# %% [markdown]
# ## Homework

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bank-full.csv', sep=';')

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
list(df.columns)
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
sel_features = ['age',
 'job',
 'marital',
 'education',
 'balance',
 'housing',
 'contact',
 'day',
 'month',
 'duration',
 'campaign',
 'pdays',
 'previous',
 'poutcome',
 'y']

# %%
df = df[sel_features]

# %%
df.head()
# Out:
#    age           job  marital  education  balance housing  contact  day month  \
# 0   58    management  married   tertiary     2143     yes  unknown    5   may
# 1   44    technician   single  secondary       29     yes  unknown    5   may
# 2   33  entrepreneur  married  secondary        2     yes  unknown    5   may
# 3   47   blue-collar  married    unknown     1506     yes  unknown    5   may
# 4   33       unknown   single    unknown        1      no  unknown    5   may
#
#    duration  campaign  pdays  previous poutcome   y
# 0       261         1     -1         0  unknown  no
# 1       151         1     -1         0  unknown  no
# 2        76         1     -1         0  unknown  no
# 3        92         1     -1         0  unknown  no
# 4       198         1     -1         0  unknown  no

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# balance      0
# housing      0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ### Question 1
#
# What is the most frequent observation (mode) for the column `education`?
#
# - `unknown`
# - `primary`
# - `secondary`
# - `tertiary`

# %%
df.education.mode()
# Out:
# 0    secondary
# Name: education, dtype: object

# %%
df.education.describe()
# Out:
# count         45211
# unique            4
# top       secondary
# freq          23202
# Name: education, dtype: object

# %% [markdown]
# ### Question 2
#
# Create the [correlation matrix](https://www.google.com/search?q=correlation+matrix) for the numerical features of your dataset.
# In a correlation matrix, you compute the correlation coefficient between every pair of features.
#
# What are the two features that have the biggest correlation?
#
# - `age` and `balance`
# - `day` and `campaign`
# - `day` and `pdays`
# - `pdays` and `previous`

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# balance       int64
# housing      object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
numerical = ["age", "balance", "day", "campaign", "pdays", "previous"]

# %%
df[numerical].corrwith(df.balance)
# Out:
# age         0.097783
# balance     1.000000
# day         0.004503
# campaign   -0.014578
# pdays       0.003435
# previous    0.016674
# dtype: float64

# %%
df[numerical].corrwith(df.day)
# Out:
# age        -0.009120
# balance     0.004503
# day         1.000000
# campaign    0.162490
# pdays      -0.093044
# previous   -0.051710
# dtype: float64

# %%
df[numerical].corrwith(df.pdays)
# Out:
# age        -0.023758
# balance     0.003435
# day        -0.093044
# campaign   -0.088628
# pdays       1.000000
# previous    0.454820
# dtype: float64

# %% [markdown]
# ### Target encoding
#
# * Now we want to encode the `y` variable.
# * Let's replace the values `yes`/`no` with `1`/`0`.

# %%
df.y = (df.y == "yes").astype(int)
df.y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45206    1
# 45207    1
# 45208    1
# 45209    0
# 45210    0
# Name: y, Length: 45211, dtype: int64

# %% [markdown]
# ### Split the data
#
# * Split your data in train/val/test sets with 60%/20%/20% distribution.
# * Use Scikit-Learn for that (the `train_test_split` function) and set the seed to `42`.
# * Make sure that the target value `y` is not in your dataframe.

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (27126, 9042, 9043)

# %%
len(df)
# Out:
# 45211

# %%
y_train = df_train.y.values
y_val = df_val.y.values
y_test = df_test.y.values

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
df_full_train = df_full_train.reset_index(drop=True)

# %%
del df_train["y"]
del df_val["y"]
del df_test["y"]

# %%
df_train.head()
# Out:
#    age            job  marital  education  balance housing   contact  day  \
# 0   32     technician   single   tertiary     1100     yes  cellular   11
# 1   38   entrepreneur  married  secondary        0     yes  cellular   17
# 2   49    blue-collar  married  secondary     3309     yes  cellular   15
# 3   37      housemaid  married    primary     2410      no  cellular    4
# 4   31  self-employed  married   tertiary     3220      no  cellular   26
#
#   month  duration  campaign  pdays  previous poutcome
# 0   aug        67         1     -1         0  unknown
# 1   nov       258         1     -1         0  unknown
# 2   may       349         2     -1         0  unknown
# 3   aug       315         1     -1         0  unknown
# 4   aug        74         4     -1         0  unknown

# %% [markdown]
# ### Question 3
#
# * Calculate the mutual information score between `y` and other categorical variables in the dataset. Use the training set only.
# * Round the scores to 2 decimals using `round(score, 2)`.
#
# Which of these variables has the biggest mutual information score?
#
# - `contact`
# - `education`
# - `housing`
# - `poutcome`

# %%
from sklearn.metrics import mutual_info_score

# %%
def mutual_info_y_score(series):
    return mutual_info_score(series, df_full_train.y)

# %%
mi = df_full_train[["contact", "education", "housing", "poutcome"]].apply(mutual_info_y_score)
mi.sort_values(ascending=False)
# Out:
# poutcome     0.029257
# contact      0.014164
# housing      0.009800
# education    0.002458
# dtype: float64

# %% [markdown]
# ### Question 4
#
# * Now let's train a logistic regression.
# * Remember that we have several categorical variables in the dataset. Include them using one-hot encoding.
# * Fit the model on the training dataset.
#     - To make sure the results are reproducible across different versions of Scikit-Learn, fit the model with these parameters:
#     - `model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)`
# * Calculate the accuracy on the validation dataset and round it to 2 decimal digits.
#
# What accuracy did you get?
#
# - 0.6
# - 0.7
# - 0.8
# - 0.9

# %%
df_train.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'balance', 'housing', 'contact',
#        'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome'],
#       dtype='object')

# %%
dicts_full_train = df_full_train[['age', 'job', 'marital', 'education', 'balance', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
       'poutcome']].to_dict(orient = "records")

# %%
dicts_full_train[:3]
# Out:
# [{'age': 41,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'primary',
#   'balance': 849,
#   'housing': 'yes',
#   'contact': 'unknown',
#   'day': 15,
#   'month': 'may',
#   'duration': 72,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown'},
#  {'age': 49,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'primary',
#   'balance': 1415,
#   'housing': 'yes',
#   'contact': 'cellular',
#   'day': 30,
#   'month': 'jul',
#   'duration': 269,
#   'campaign': 2,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown'},
#  {'age': 42,
#   'job': 'admin.',
#   'marital': 'married',
#   'education': 'secondary',
#   'balance': 3842,
#   'housing': 'no',
#   'contact': 'cellular',
#   'day': 31,
#   'month': 'jul',
#   'duration': 130,
#   'campaign': 4,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown'}]

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression

# %%
dv = DictVectorizer(sparse=False)
X_full_train = dv.fit_transform(dicts_full_train)
y_full_train = df_full_train.y.values

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)

# %%
model.fit(X_full_train, y_full_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
X_full_train
# Out:
# array([[ 4.100e+01,  8.490e+02,  1.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        [ 4.900e+01,  1.415e+03,  2.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        [ 4.200e+01,  3.842e+03,  4.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        ...,
#        [ 3.400e+01,  1.317e+03,  1.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        [ 3.300e+01,  1.650e+02,  1.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00],
#        [ 3.800e+01, -4.100e+01,  1.000e+01, ...,  0.000e+00,  1.000e+00,
#          0.000e+00]])

# %%
val_dicts = df_val[['age', 'job', 'marital', 'education', 'balance', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
       'poutcome']].to_dict(orient="records")
X_val = dv.transform(val_dicts)

# %%
y_pred = model.predict_proba(X_val)[:,1]
y_decision = (y_pred >= 0.5)

# %%
accuracy = (y_val == y_decision).mean()
accuracy
# Out:
# np.float64(0.900464499004645)

# %% [markdown]
# ### Question 5
#
# * Let's find the least useful feature using the *feature elimination* technique.
# * Train a model with all these features (using the same parameters as in Q4).
# * Now exclude each feature from this set and train a model without it. Record the accuracy for each model.
# * For each feature, calculate the difference between the original accuracy and the accuracy without the feature.
#
# Which of following feature has the smallest difference?
#
# - `age`
# - `balance`
# - `marital`
# - `previous`
#
# > **Note**: The difference doesn't have to be positive.

# %%
age_dicts_full_train = df_full_train[['job', 'marital', 'education', 'balance', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
       'poutcome']].to_dict(orient = "records")
bal_dicts_full_train = df_full_train[['age', 'job', 'marital', 'education', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
       'poutcome']].to_dict(orient = "records")
mar_dicts_full_train = df_full_train[['age', 'job', 'education', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
       'poutcome']].to_dict(orient = "records")
prev_dicts_full_train = df_full_train[['age', 'job', 'marital', 'education', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays', 'poutcome']].to_dict(orient = "records")

# %%
dv = DictVectorizer(sparse=False)
age_X_full_train = dv.fit_transform(age_dicts_full_train)

# %%
model.fit(age_X_full_train, y_full_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
age_val_dicts = df_val[['age', 'job', 'marital', 'education', 'balance', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
       'poutcome']].to_dict(orient="records")
bal_val_dicts = df_val[['age', 'job', 'marital', 'education', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
       'poutcome']].to_dict(orient="records")
mar_val_dicts = df_val[['age', 'job', 'education', 'balance', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
       'poutcome']].to_dict(orient="records")
prev_val_dicts = df_val[['age', 'job', 'marital', 'education', 'balance', 'housing', 'contact',
       'day', 'month', 'duration', 'campaign', 'pdays',
       'poutcome']].to_dict(orient="records")


age_X_val = dv.transform(age_val_dicts)

# %% [markdown]
# age_y_pred = model.predict_proba(age_X_val)[:,1]
# age_y_decision = (age_y_pred >= 0.5)

# %%
age = (y_val == age_y_decision).mean()
age
# Out:
# np.float64(0.9001327140013271)

# %% [markdown]
# Balance

# %%
bal_X_full_train = dv.fit_transform(bal_dicts_full_train)
model.fit(bal_X_full_train, y_full_train)
bal_X_val = dv.transform(bal_val_dicts)
bal_y_pred = model.predict_proba(bal_X_val)[:,1]
bal_y_decision = (bal_y_pred >= 0.5)
bal = (y_val == bal_y_decision).mean()
bal
# Out:
# np.float64(0.9010174740101747)

# %% [markdown]
# Marital

# %%
mar_X_full_train = dv.fit_transform(mar_dicts_full_train)
model.fit(mar_X_full_train, y_full_train)
mar_X_val = dv.transform(mar_val_dicts)
mar_y_pred = model.predict_proba(mar_X_val)[:,1]
mar_y_decision = (mar_y_pred >= 0.5)
mar = (y_val == mar_y_decision).mean()
mar
# Out:
# np.float64(0.9009068790090687)

# %% [markdown]
# Previous

# %%
prev_X_full_train = dv.fit_transform(prev_dicts_full_train)
model.fit(prev_X_full_train, y_full_train)
prev_X_val = dv.transform(prev_val_dicts)
prev_y_pred = model.predict_proba(prev_X_val)[:,1]
prev_y_decision = (prev_y_pred >= 0.5)
prev = (y_val == prev_y_decision).mean()
prev
# Out:
# np.float64(0.9010174740101747)

# %%
accuracy - age, accuracy - bal, accuracy - mar, accuracy - prev
# Out:
# (np.float64(0.00033178500331787486),
#  np.float64(-0.0005529750055297544),
#  np.float64(-0.00044238000442375913),
#  np.float64(-0.0005529750055297544))

# %% [markdown]
# ### Question 6
#
# * Now let's train a regularized logistic regression.
# * Let's try the following values of the parameter `C`: `[0.01, 0.1, 1, 10, 100]`.
# * Train models using all the features as in Q4.
# * Calculate the accuracy on the validation dataset and round it to 3 decimal digits.
#
# Which of these `C` leads to the best accuracy on the validation set?
#
# - 0.01
# - 0.1
# - 1
# - 10
# - 100

# %%
for c in [0.01, 0.1, 1, 10, 100]:
    dv = DictVectorizer(sparse=False)
    X_full_train = dv.fit_transform(dicts_full_train)
    y_full_train = df_full_train.y.values
    model = LogisticRegression(solver='liblinear', C=c, max_iter=1000, random_state=42)
    model.fit(X_full_train, y_full_train)
    y_pred = model.predict_proba(X_val)[:,1]
    y_decision = (y_pred >= 0.5)
    accuracy = (y_val == y_decision).mean()
    print(c, accuracy)
# Out:
# 0.01 0.8989161689891617
# 0.1 0.9006856890068569
# 1 0.900464499004645
# 10 0.900464499004645
# 100 0.900575094005751
